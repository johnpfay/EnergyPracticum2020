# %% [markdown]
# https://developer.nrel.gov/docs/transportation/alt-fuel-stations-v1/

# %%
import pandas as pd
import requests
from arcgis.features import GeoAccessor

# %%
key='aaAlDXFiFfVotWqNbzXiZSF73908ZbcGo0MIoWZe'

# %%
baseURL = 'https://developer.nrel.gov/api/alt-fuel-stations/v1.{}?'.format('json')
params = {
    'api_key':key,
    'status':'all',
    'access':'',
    'fuel_type':'ELEC',
    'state':'NC'
}

# %%
result = requests.get(baseURL,params).json()

# %%
df = pd.DataFrame(result['fuel_stations'])
df.shape
# Out:
# (746, 63)

# %%
#Convert to spatial dataframe
sdf = GeoAccessor.from_xy(df,x_column='longitude',y_column='latitude')

# %%
sdf.plot(x='longitude',y='latitude',kind='scatter',grid=1);

# %%
sdfX = sdf.iloc[:,-10:]
sdf[['status_code','SHAPE']].spatial.plot()
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-754b6019-7344-411c-81e8-168177706f04"><img src=""></img></div>
